# %% [markdown]
# **Use WordNet to identify semantic relationships such as synonymy, antonymy, and hypernymy in text data.**

# %%
# !pip install nltk

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize

# %%
# Function to get synonyms of a word using WordNet
def get_synonyms(word):
    synonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return list(synonyms)

# %%
# Function to get antonyms of a word using WordNet
def get_antonyms(word):
    antonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
    return list(antonyms)

# %%
# Function to get hypernyms (broader category words)
def get_hypernyms(word):
    hypernyms = set()
    for syn in wn.synsets(word):
        for hyper in syn.hypernyms():
            hypernyms.add(hyper.name().split('.')[0])
    return list(hypernyms)

# %%
# Function to analyze text and extract semantic relationships
def analyze_text_semantics(text):
    tokens = word_tokenize(text.lower())
    results = {}

    for word in tokens:
        if word.isalpha():
            results[word] = {
                "synonyms": get_synonyms(word),
                "antonyms": get_antonyms(word),
                "hypernyms": get_hypernyms(word)
            }
    return results

# %%
text = "Artificial intelligence is transforming modern healthcare and education systems."

semantic_info = analyze_text_semantics(text)

for word, relations in semantic_info.items():
    print(f"\nWord: {word}")
    print("Synonyms:", relations["synonyms"][:5])
    print("Antonyms:", relations["antonyms"])
    print("Hypernyms:", relations["hypernyms"])
# Out:
# Word: artificial
# Synonyms: ['artificial', 'hokey', 'stilted', 'contrived', 'unreal']
# Antonyms: ['natural']
# Hypernyms: []
#
# Word: intelligence
# Synonyms: ['intelligence', 'intelligence_service', 'news', 'intelligence_agency', 'intelligence_activity']
# Antonyms: ['stupidity']
# Hypernyms: ['information_gathering', 'information', 'administrative_unit', 'ability']
#
# Word: is
# Synonyms: ['make_up', 'personify', 'equal', 'exist', 'embody']
# Antonyms: ['differ']
# Hypernyms: ['take', 'typify', 'stay', 'be']
#
# Word: transforming
# Synonyms: ['transubstantiate', 'translate', 'transmute', 'metamorphose', 'transform']
# Antonyms: []
# Hypernyms: ['change']
#
# Word: modern
# Synonyms: ['modernistic', 'advanced', 'New', 'modern', 'forward-looking']
# Antonyms: ['nonmodern', 'old_style']
# Hypernyms: ['proportional_font', 'person']
#
# Word: healthcare
# Synonyms: ['health_care', 'healthcare']
# Antonyms: []
# Hypernyms: ['care']
#
# Word: and
# Synonyms: []
# Antonyms: []
# ...

# %%
word = "intelligent"
print("Synonyms:", get_synonyms(word))
print("Antonyms:", get_antonyms(word))
print("Hypernyms:", get_hypernyms(word))
# Out:
# Synonyms: ['thinking', 'well-informed', 'sound', 'intelligent', 'reasoning', 'healthy', 'level-headed', 'levelheaded']
# Antonyms: ['unintelligent']
# Hypernyms: []
